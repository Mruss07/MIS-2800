# %% [markdown]
# <a href="https://colab.research.google.com/github/Mruss07/MIS-2800/blob/main/Hello_world.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Hello World")
# Out:
# Hello World

# %%
print (" MIS is best")
# Out:
#  MIS is best
