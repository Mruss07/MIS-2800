# %% [markdown]
# <a href="https://colab.research.google.com/github/Mruss07/MIS-2800/blob/main/IC3_Week4_RUSS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Type this code exactly as shown to intall the first library needed for SQLite3 to work using SQLite Magic
# !pip install --upgrade pandas ipython-sql prettytable==3.10.1

# %%
# Install the SQL extension. Remember to type exactly as shown here.
# !pip install ipython-sql
print("ipython sql installed")
# Out:
# ...
# ipython sql installed

# %%
# Load the SQL magic extention
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
#this code imports sqlite3 and prints a statement stating it has been imported
import sqlite3
print("sqlite3 imported")
# Out:
# sqlite3 imported

# %%
# This creates a brand-new, empty database file named 'SuperBowl_Finance.db'
conn = sqlite3.connect('SuperBowl_Finance.db')
print("SuperBowl_Finance database created")
# Out:
# SuperBowl_Finance database created

# %%
# This line is required so Colab stops acting like Python and acts more like a SQL database terminal
# %sql sqlite:///SuperBowl_Finance.db

# %% [markdown]
# #Blocks 1-11

# %%
#Block 1
# Instructions: Create a table named stock_performance with columns for ticker, price_before_game, price_week_after_
# %%sql
CREATE TABLE IF NOT EXISTS stock_performance (
    ticker TEXT,
    price_before_game REAL,
    price_week_after_game REAL
) STRICT;
# Out:
#  * sqlite:///SuperBowl_Finance.db
# Done.
# []

# %%
# Block 2
# Instructions: Add the below values into the stock_performance table
# %%sql
INSERT INTO stock_performance(ticker, price_before_game, price_week_after_game, trading_volume_millions)
VALUES
  ('Pep', 168.50, 172.10, 45),
  ('GOOGL', 142.80, 145.20, 110),
  ('AMZN', 170.20, 178.45, 95),
  ('VZ', 40.10, 39.85, 60),
  ('TSLA', 190.00, 185.20, 150),
  ('TMUS', 197.68, 199.34, 100),
  ('STLA', 22.40, 23.10, 15);
# Out:
#  * sqlite:///SuperBowl_Finance.db
# 7 rows affected.
# []

# %%
#Block 3
# Instructions: Create a table named Ad_Buys with columns for ticker, company_name, ad_cost_millions, airtime_second
# The ticker should be a TEXT data type and serve as the Primary Key.
# Select an appropriate data_type for the other columns.
# Remember to use the STRICT keyword to ensure the datatype is enforced.
# %%sql
-- creating another table named ad_buys
CREATE TABLE IF NOT EXISTS ad_buys (
    ticker TEXT PRIMARY KEY,
    company_name TEXT,
    ad_cost_millions REAL,
    airtime_seconds INTEGER
) STRICT;
# Out:
#  * sqlite:///SuperBowl_Finance.db
# Done.
# []

# %%
#Block 4
# %%sql
INSERT OR IGNORE INTO ad_buys (ticker, company_name, ad_cost_millions, airtime_seconds)
VALUES
  ('PEP', 'PepsiCo', 7.0, 3.0),
  ('GOOGL', '(Google)', 14.0, 60),
  ('AMZN', 'Amazon', 14.0, 60),
  ('VZ', 'Verizon', 7.0, 30),
  ('TSLA', 'Tesla', 0.0, 0), -- Tesla doesn't buy ads
  ('TMUS', 'Tmobile', 10.0, 30),
  ('STLA', 'Stellantis (Jeep)', 6.5, 30);
# Out:
#  * sqlite:///SuperBowl_Finance.db
# 0 rows affected.
# []

# %%
#Block 5
# Instructions: Show all the columns from the stock_performance table
# %%sql
SELECT * FROM stock_performance;
# Out:
#  * sqlite:///SuperBowl_Finance.db
# Done.
# [('PEP', 168.5, 172.1, 45),
#  ('GOOGL', 142.8, 145.2, 110),
#  ('AMZN', 170.2, 178.45, 95),
#  ('VZ', 40.1, 39.85, 60),
#  ('TSLA', 190.0, 185.2, 150),
#  ('TMUS', 197.68, 199.34, 100),
#  ('STLA', 22.4, 23.1, 15),
#  ('PEP', 168.5, 172.1, 45),
#  ('GOOGL', 142.8, 145.2, 110),
#  ('AMZN', 170.2, 178.45, 95),
#  ('VZ', 40.1, 39.85, 60),
#  ('TSLA', 190.0, 185.2, 150),
#  ('TMUS', 197.68, 199.34, 100),
#  ('STLA', 22.4, 23.1, 15),
#  ('Pep', 168.5, 172.1, 45),
#  ('GOOGL', 142.8, 145.2, 110),
#  ('AMZN', 170.2, 178.45, 95),
#  ('VZ', 40.1, 39.85, 60),
#  ('TSLA', 190.0, 185.2, 150),
#  ('TMUS', 197.68, 199.34, 100),
#  ('STLA', 22.4, 23.1, 15),
#  ('Pep', 168.5, 172.1, 45),
#  ('GOOGL', 142.8, 145.2, 110),
#  ('AMZN', 170.2, 178.45, 95),
#  ('VZ', 40.1, 39.85, 60),
#  ('TSLA', 190.0, 185.2, 150),
#  ('TMUS', 197.68, 199.34, 100),
#  ('STLA', 22.4, 23.1, 15),
#  ('Pep', 168.5, 172.1, 45),
#  ('GOOGL', 142.8, 145.2, 110),
# ...

# %%
#Block 6
# # Instructions: Show the ticker and price before the game
# sort by ticker in alphabetical order from the stock_performance table
# %%sql
SELECT ticker, price_before_game FROM stock_performance ORDER BY ticker ASC;
# Out:
#  * sqlite:///SuperBowl_Finance.db
# Done.
# [('AMZN', 170.2),
#  ('AMZN', 170.2),
#  ('AMZN', 170.2),
#  ('AMZN', 170.2),
#  ('AMZN', 170.2),
#  ('GOOGL', 142.8),
#  ('GOOGL', 142.8),
#  ('GOOGL', 142.8),
#  ('GOOGL', 142.8),
#  ('GOOGL', 142.8),
#  ('PEP', 168.5),
#  ('PEP', 168.5),
#  ('Pep', 168.5),
#  ('Pep', 168.5),
#  ('Pep', 168.5),
#  ('STLA', 22.4),
#  ('STLA', 22.4),
#  ('STLA', 22.4),
#  ('STLA', 22.4),
#  ('STLA', 22.4),
#  ('TMUS', 197.68),
#  ('TMUS', 197.68),
#  ('TMUS', 197.68),
#  ('TMUS', 197.68),
#  ('TMUS', 197.68),
#  ('TSLA', 190.0),
#  ('TSLA', 190.0),
#  ('TSLA', 190.0),
#  ('TSLA', 190.0),
#  ('TSLA', 190.0),
#  ('VZ', 40.1),
#  ('VZ', 40.1),
#  ('VZ', 40.1),
#  ('VZ', 40.1),
#  ('VZ', 40.1)]

# %%
#Block 7
# # Instructions: Show all the columns for the brands that have a ticker
# beginning with the letter T in the stock_performance table
# %%sql
SELECT * FROM stock_performance WHERE ticker LIKE 'T%';
# Out:
#  * sqlite:///SuperBowl_Finance.db
# Done.
# [('TSLA', 190.0, 185.2, 150),
#  ('TMUS', 197.68, 199.34, 100),
#  ('TSLA', 190.0, 185.2, 150),
#  ('TMUS', 197.68, 199.34, 100),
#  ('TSLA', 190.0, 185.2, 150),
#  ('TMUS', 197.68, 199.34, 100),
#  ('TSLA', 190.0, 185.2, 150),
#  ('TMUS', 197.68, 199.34, 100),
#  ('TSLA', 190.0, 185.2, 150),
#  ('TMUS', 197.68, 199.34, 100)]

# %%
#Block 8
# # Instructions: Show only the ticker and price_after_game
# from the stock_performance table if the price is above 150
# %%sql
SELECT ticker, price_week_after_game FROM stock_performance WHERE price_week_after_game > 150;
# Out:
#  * sqlite:///SuperBowl_Finance.db
# Done.
# [('PEP', 172.1),
#  ('AMZN', 178.45),
#  ('TSLA', 185.2),
#  ('TMUS', 199.34),
#  ('PEP', 172.1),
#  ('AMZN', 178.45),
#  ('TSLA', 185.2),
#  ('TMUS', 199.34),
#  ('Pep', 172.1),
#  ('AMZN', 178.45),
#  ('TSLA', 185.2),
#  ('TMUS', 199.34),
#  ('Pep', 172.1),
#  ('AMZN', 178.45),
#  ('TSLA', 185.2),
#  ('TMUS', 199.34),
#  ('Pep', 172.1),
#  ('AMZN', 178.45),
#  ('TSLA', 185.2),
#  ('TMUS', 199.34)]

# %%
#Block 9
# Instructions: Show all the columns from the ad_buys table
# %%sql
SELECT * FROM ad_buys;
# Out:
#  * sqlite:///SuperBowl_Finance.db
# Done.
# [('GOOGL', 'Alphabet\xa0(Google)', 15.0, 60),
#  ('AMZN', 'Amazon', 14.0, 60),
#  ('VZ', 'Verizon', 7.0, 30),
#  ('TSLA', 'Tesla', 0.0, 0),
#  ('TMUS', 'Tmobile', 10.0, 30),
#  ('STLA', 'Stellantis\xa0(Jeep)', 6.5, 30),
#  ('PEP', 'PepsiCo New Info', 8.0, 45)]

# %%
#Block 10
# # Instructions: Show the ticker and company_name from the ad_buys table in
# sort in descending order by company_name
# %%sql
SELECT ticker, company_name FROM ad_buys ORDER BY company_name DESC;
# Out:
#  * sqlite:///SuperBowl_Finance.db
# Done.
# [('VZ', 'Verizon'),
#  ('TMUS', 'Tmobile'),
#  ('TSLA', 'Tesla'),
#  ('STLA', 'Stellantis\xa0(Jeep)'),
#  ('PEP', 'PepsiCo New Info'),
#  ('AMZN', 'Amazon'),
#  ('GOOGL', 'Alphabet\xa0(Google)')]

# %%
#Block 11
# # Instructions: Show the ticker and airtime seconds from the ad_buys table
# Filter to show only if the ticker begins with T and and airtime seconds is 0
# %%sql
SELECT ticker, airtime_seconds FROM ad_buys WHERE ticker LIKE 'T%' AND airtime_seconds = 0
# Out:
#  * sqlite:///SuperBowl_Finance.db
# Done.
# [('TSLA', 0)]
