# %% [markdown]
# <a href="https://colab.research.google.com/github/Mruss07/MIS-2800/blob/main/RUSS_HW3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade pandas ipython-sql prettytable==3.10.1

# %%
# !pip install ipython-sql
print("ipython sql installed")
# Out:
# ...
# ipython sql installed

# %%
# %load_ext sql

# %%
import sqlite3
print("sqlite3 imported")
# Out:
# sqlite3 imported

# %%
conn = sqlite3.connect('AdCampaigns2026.db')
print("database created")
# Out:
# database created

# %%
# %sql sqlite:///AdCampaigns2026.db

# %%
# %%sql
# CREATE TABLE Marketing_Brands (
#   brand_id INTEGER PRIMARY KEY,
#   brand_name TEXT,
#   brand_type TEXT,
#   brand_budget INTEGER
# ) STRICT;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# []

# %%
# %%sql
# INSERT INTO Marketing_Brands (brand_id, brand_name, brand_type, brand_budget)
# VALUES
#   (1, 'Doritos', 'Snacks', 7000000),
#   (2, 'AWS', 'Technology', 15000000),
#   (3, 'Pepsi', 'Beverages', 2000000),
#   (4, 'He_Gets_Us', 'Religious', 1000000),
#   (5, 'Dr_Pepper', 'Beverages', 5000000),
#   (6, 'IBM', 'Technology', 100000),
#   (7, 'Google', 'Technology', 8000000);
# Out:
#  * sqlite:///AdCampaigns2026.db
# 7 rows affected.
# []

# %%
# %%sql
# -- Instructions: Fix the code to select all the columns from the Marketing_Brands
# SELECT * FROM Marketing_Brands;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(1, 'Doritos', 'Snacks', 7000000),
#  (2, 'AWS', 'Technology', 15000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (6, 'IBM', 'Technology', 100000),
#  (7, 'Google', 'Technology', 8000000)]

# %%
# %%sql
# /*
# Instructions: Fix the code to display only the brand names and
# brand types that had budget over 700000
# */
# SELECT brand_name, brand_type
# FROM Marketing_Brands
# WHERE brand_budget > 700000;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos', 'Snacks'),
#  ('AWS', 'Technology'),
#  ('Pepsi', 'Beverages'),
#  ('He_Gets_Us', 'Religious'),
#  ('Dr_Pepper', 'Beverages'),
#  ('Google', 'Technology')]

# %%
# %%sql
# -- Instructions: Fix the code to find the brand types that are Religious
# SELECT * FROM Marketing_Brands WHERE brand_type = 'Religious';
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(4, 'He_Gets_Us', 'Religious', 1000000)]

# %%
#Block 6
# -- Instructions: Fix the code to display the
# brand names that have a budget under 1000000
# %%sql
SELECT brand_name FROM Marketing_Brands WHERE brand_budget < 1000000;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('IBM',)]

# %%
# %%sql
# -- Block 7
# -- Instructions: Fix the code so that this will run SQLite3 in
# -- Colab without having to wrap in Python. Hint: It's Magic!
# SELECT * FROM Marketing_Brands WHERE brand_budget > 700000
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(1, 'Doritos', 'Snacks', 7000000),
#  (2, 'AWS', 'Technology', 15000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (7, 'Google', 'Technology', 8000000)]

# %%
# %%sql
# SELECT brand_name
# FROM Marketing_Brands
# WHERE brand_type IN ('Snacks', 'Beverages');
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('Doritos',), ('Pepsi',), ('Dr_Pepper',)]

# %%
# %%sql
# SELECT brand_name, brand_budget
# FROM Marketing_Brands
# ORDER BY brand_budget DESC;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('AWS', 15000000),
#  ('Google', 8000000),
#  ('Doritos', 7000000),
#  ('Dr_Pepper', 5000000),
#  ('Pepsi', 2000000),
#  ('He_Gets_Us', 1000000),
#  ('IBM', 100000)]

# %%
# %%sql
# -- Using SQLite3 to display all columns in ascending order by budget.
# SELECT *
# FROM Marketing_Brands
# ORDER BY brand_budget ASC;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(6, 'IBM', 'Technology', 100000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (1, 'Doritos', 'Snacks', 7000000),
#  (7, 'Google', 'Technology', 8000000),
#  (2, 'AWS', 'Technology', 15000000)]

# %% [markdown]
# #BLOCK 1 Missing the word TABLE after CREATE

# %% [markdown]
# #BLOCK 2 Missing "INTO Marketing_Brands" after "INSERT"

# %% [markdown]
# #BLOCK 3 Missing "*" between SELECT and FROM

# %% [markdown]
# #BLOCK 4 Added "brand_name, brand_type" after SELECT
# # Added "Marketing_Brands" after FROM
# # Added "WHERE brand_budget > 700000"

# %% [markdown]
# #BLOCK 5 Added * bewteen "SELECT and FROM"
# # Added "WHERE brand_type = 'Religous';"

# %% [markdown]
# #BLOCK 6 Added "brand_name before "FROM"
# # Added "brand_budget < 1000000" after WHERE

# %% [markdown]
# #BLOCK 7 Added %%sql magic command

# %% [markdown]
# #BLOCK 8 Added "brand_name" after SELECT
# #Added "WHERE brand_type IN ('Snacks', 'Beverages');" after "FROM Marketing_Brands"

# %% [markdown]
# #BLOCK 9 Added "brand_name, brand_budget
# # From Marketing_Brands
# # ORDER BY brand_budget DESC;" after "SELECT"

# %% [markdown]
# #BLOCK 10 Added "SELECT *
# #       FROM Marketing_Brands
# #       ORDER BY brand_budget ASC;"
